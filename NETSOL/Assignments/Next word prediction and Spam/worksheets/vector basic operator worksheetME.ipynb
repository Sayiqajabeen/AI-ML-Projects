# %% [markdown]
# # Exercise 1: Basic Vector Operations

# %%
import numpy as np

# Create two vectors
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# %%
x=v1+v2
print(x)
# Out:
# [5 7 9]

# %%
import numpy as np

# Create two vectors
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# 1. Vector addition
def vector_addition(a, b):
    return a+b

# 2. Vector subtraction
def vector_subtraction(a, b):
    return a-b

# 3. Dot product
def dot_product(a, b):
    return np.dot(a,b)

# 4. Cross product (for 3D vectors)
def cross_product(a, b):
    return np.cross(a,b)

# 5. Vector magnitude
def vector_magnitude(a):
    return np.linalg.norm(a)# Your code here


# Test your functions
print("Addition:", vector_addition(v1, v2))
print("Subtraction:", vector_subtraction(v1, v2))
print("Dot product:", dot_product(v1, v2))
print("Cross product:", cross_product(v1, v2))
print("Magnitude v1:", vector_magnitude(v1))
# Out:
# Addition: [5 7 9]
# Subtraction: [-3 -3 -3]
# Dot product: 32
# Cross product: [-3  6 -3]
# Magnitude v1: 3.7416573867739413

# %% [markdown]
# # Exercise 2: Basic Matrix Operations

# %%
# Create two matrices
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])

# 1. Matrix addition
def matrix_addition(a, b):
    return a+b 

# 2. Matrix subtraction
def matrix_subtraction(a, b):
    return a-b

# 3. Matrix multiplication
def matrix_multiplication(a, b):
    return np.dot(a, b)

# 4. Matrix transpose
def matrix_transpose(a):
    return np.transpose(a)

# 5. Matrix determinant (for square matrices)
def matrix_determinant(a):
    return np.linalg.det(a)

# Test your functions
print("Matrix addition:\n", matrix_addition(m1, m2))
print("Matrix subtraction:\n", matrix_subtraction(m1, m2))
print("Matrix multiplication:\n", matrix_multiplication(m1, m2))
print("Matrix transpose m1:\n", matrix_transpose(m1))
print("Matrix determinant m1:", matrix_determinant(m1))
# Out:
# Matrix addition:
#  [[ 6  8]
#  [10 12]]
# Matrix subtraction:
#  [[-4 -4]
#  [-4 -4]]
# Matrix multiplication:
#  [[19 22]
#  [43 50]]
# Matrix transpose m1:
#  [[1 3]
#  [2 4]]
# Matrix determinant m1: -2.0000000000000004

# %% [markdown]
# # Exercise 3: Vector Transformations and Angle Calculation

# %%
v1=np.array([1,2,3])
v2=np.array([4,5,6]) 

v = np.array([1, 0])

# %%
v1=np.linalg.norm(v1)
v2=np.linalg.norm(v2)

# 1. Vector scaling
def scale_vector(v, scalar):
    return v*scalar

# 2. Angle between two vectors (in radians)
def angle_between_vectors(v1, v2):
    cos_theta = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))
    return np.arccos(np.clip(cos_theta, -1.0, 1.0))

# 3. Vector projection of a onto b
def vector_projection(v1, v2):
     return np.dot(v1, v2) / np.dot(v2, v2) * v2

# 4. Rotate a 2D vector by theta radians
# def rotate_vector_2d(v, theta):
#     rotation_matrix=np.array([np.cos(theta),-np.sin(theta)],
#                               [np.sin(theta),-np.cos(theta)]) 
#     return np.dot(rotation_matrix,v)
def rotate_vector_2d(v, theta):
    rotation_matrix = np.array([
        [np.cos(theta), -np.sin(theta)],
        [np.sin(theta),  np.cos(theta)]
    ])
    
    return np.dot(rotation_matrix, v)




# Test your functions
v = np.array([1, 0])
print("Scaled vector:", scale_vector(v, 2.5))
print("Angle between v1 and v2:", angle_between_vectors(v1, v2))
print("Projection of v1 onto v2:", vector_projection(v1, v2))
print("Rotated vector:", rotate_vector_2d(v, np.pi/2))  # 90 degrees
# Out:
# Scaled vector: [2.5 0. ]
# Angle between v1 and v2: 0.0
# Projection of v1 onto v2: 3.741657386773941
# Rotated vector: [6.123234e-17 1.000000e+00]

# %% [markdown]
# # Exercise 4: Eigenvalues and Eigenvectors

# %%
A=np.array([[2,-1],[-1,2]])
A
# Out:
# array([[ 2, -1],
#        [-1,  2]])

# %%
import numpy as np 
# 1. Compute eigenvalues and eigenvectors
def compute_eigen(matrix):
    eigenvalues, eigenvectors=np.linalg.eig(matrix)
    return eigenvalues, eigenvectors
    

# 2. Verify that Av = λv for the first eigenvalue/eigenvector pair
def verify_eigen(matrix, eigenvalues, eigenvectors):
    λ = eigenvalues[0]
    v = eigenvectors[:, 0]
    #: all rows, 0 take the first column
    Av = np.dot(matrix, v)
    λv = λ * v
    print("Av:", Av)
    print("λv:", λv)
    print("Are they equal?", np.allclose(Av, λv))

# Test with a sample matrix
sample_matrix = np.array([[2, -1], [-1, 2]])
eigenvalues, eigenvectors = compute_eigen(sample_matrix)
print("Eigenvalues:", eigenvalues)
print("Eigenvectors:\n", eigenvectors)
verify_eigen(sample_matrix, eigenvalues, eigenvectors)
# Out:
# Eigenvalues: [3. 1.]
# Eigenvectors:
#  [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]
# Av: [ 2.12132034 -2.12132034]
# λv: [ 2.12132034 -2.12132034]
# Are they equal? True

# %% [markdown]
# # Exercise 5: Grouping Data Points by Angular Similarity

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in .\.venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in .\.venv\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data[:, :2]  # Using only sepal length and width
y = iris.target

def calculate_angle(a, b):
    """Calculate the angle between two vectors in degrees"""
    # STUDENT TODO:
    # 1. Normalize vectors a and b (convert to unit vectors)
    a = a / np.linalg.norm(a)
    b = b / np.linalg.norm(b)
    # 2. Compute dot product
    dot_product = np.dot(a, b)
    # 3. Use arccos to get angle in radians
    angle_rad = np.arccos(np.clip(dot_product, -1.0, 1.0))
    # 4. Convert to degrees
    return np.degrees(angle_rad)  # Replace with your implementation

def group_by_angle(data, angle_threshold=30):
    """Group data points based on angular similarity"""
    n_samples = data.shape[0]
    groups = np.zeros(n_samples, dtype=int)
    current_group = 0

    for i in range(n_samples):
        if groups[i] == 0:  # If point isn't assigned yet
            groups[i] = current_group
            for j in range(i+1, n_samples):
                angle = calculate_angle(data[i], data[j])
                # TODO:
                # If angle < threshold, assign to same group
                pass
            current_group += 1
    return groups

# Run grouping
angle_threshold = 30  # degrees
groups = group_by_angle(X, angle_threshold)

# Visualize results
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=groups, cmap='tab20', alpha=0.7)
plt.title(f"Data Grouping by Angle (Threshold: {angle_threshold}°)")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.colorbar(label='Group ID')
plt.grid(True)
plt.show()
