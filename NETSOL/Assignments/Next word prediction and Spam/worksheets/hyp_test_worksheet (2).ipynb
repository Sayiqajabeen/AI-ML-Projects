# %% [markdown]
# # 📝 Hypothesis Testing Worksheet: The Case of the Multiple-Choice Exam
#
# ---
# ## ⚖️ Your Turn to Be the Judge!
#
# In the lecture, we investigated a True/False exam. Now, it's your turn to apply the same reasoning to a new case.
#
# ### 🏛️ The New Case
#
# A different student takes a **20-question multiple-choice exam**. Each question has **4 options** (A, B, C, or D), with only one correct answer.
#
# This student scores **9 out of 20**.
#
# The teacher is again suspicious and brings the student to the principal. The student claims:
#
# > *"I didn't cheat! I just guessed randomly on every question!"*
#
# The principal must decide: **Did the student cheat, or did they just get unlucky on a bad guessing day?**
#
# Your task is to conduct a hypothesis test to help the principal make a decision.
#
# ---
# **Reminder of the Courtroom Analogy:**
# *   **H₀ (Null Hypothesis):** Student is **Innocent** (guessing randomly).
# *   **H₁ (Alternative Hypothesis):** Student is **Guilty** (cheating, scoring higher than random chance).
# *   **Evidence:** The score of **9/20**.
# *   **Threshold (α):** We'll use the standard **α = 0.05**.
#
# ---

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Collecting numpy
#   Downloading numpy-2.4.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas
#   Using cached pandas-3.0.1-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ali\desktop\hypothesis_testing_courtroom\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.0-cp314-cp314-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ali\desktop\hypothesis_testing_courtroom\venv\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.1-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ali\desktop\hypothesis_testing_courtroom\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading numpy-2.4.3-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 541.7 kB/s eta 0:00:23
#    - -------------------------------------- 0.5/12.4 MB 541.7 kB/s eta 0:00:23
#    -- ------------------------------------- 0.8/12.4 MB 565.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/12.4 MB 565.6 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/12.4 MB 565.6 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/12.4 MB 564.6 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/12.4 MB 564.6 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.3/12.4 MB 539.0 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.3/12.4 MB 539.0 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.3/12.4 MB 539.0 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.6/12.4 MB 526.7 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.6/12.4 MB 526.7 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.8/12.4 MB 522.7 kB/s eta 0:00:21
#    ----- ---------------------------------- 1.8/12.4 MB 522.7 kB/s eta 0:00:21
#    ------ --------------------------------- 2.1/12.4 MB 530.7 kB/s eta 0:00:20
#    ------ --------------------------------- 2.1/12.4 MB 530.7 kB/s eta 0:00:20
#    ------ --------------------------------- 2.1/12.4 MB 530.7 kB/s eta 0:00:20
#    ------- -------------------------------- 2.4/12.4 MB 534.0 kB/s eta 0:00:19
#    ------- -------------------------------- 2.4/12.4 MB 534.0 kB/s eta 0:00:19
#    -------- ------------------------------- 2.6/12.4 MB 528.3 kB/s eta 0:00:19
#    -------- ------------------------------- 2.6/12.4 MB 528.3 kB/s eta 0:00:19
#    -------- ------------------------------- 2.6/12.4 MB 528.3 kB/s eta 0:00:19
#    --------- ------------------------------ 2.9/12.4 MB 516.2 kB/s eta 0:00:19
#    ----------------- ---------------------- 1.0/2.3 MB 232.8 kB/s eta 0:00:06
#    ----------------- ---------------------- 1.0/2.3 MB 232.8 kB/s eta 0:00:06
#    ----------------- ---------------------- 1.0/2.3 MB 232.8 kB/s eta 0:00:06
#    ----------------- ---------------------- 1.0/2.3 MB 232.8 kB/s eta 0:00:06
#    ----------------- ---------------------- 1.0/2.3 MB 232.8 kB/s eta 0:00:06
#    ----------------- ---------------------- 1.0/2.3 MB 232.8 kB/s eta 0:00:06
#    ---------------------- ----------------- 1.3/2.3 MB 227.4 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.3 MB 227.4 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.3 MB 227.4 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.3 MB 227.4 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.3 MB 227.4 kB/s eta 0:00:05
#    -------------------------- ------------- 1.6/2.3 MB 231.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.3 MB 231.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.3 MB 231.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.3 MB 231.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.3 MB 231.0 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.3 MB 233.9 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.3 MB 233.9 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.3 MB 233.9 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.3 MB 233.9 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.3 MB 233.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 236.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 236.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 236.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 236.3 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.3 MB 236.3 kB/s eta 0:00:02
#    ---------------------------------------- 2.3/2.3 MB 235.5 kB/s  0:00:09
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Using cached pillow-12.1.1-cp314-cp314-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib, seaborn
#
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    ----------------------------------------  0/15 [tzdata]
#    -- -------------------------------------  1/15 [threadpoolctl]
#    ----- ----------------------------------  2/15 [pyparsing]
#    ----- ----------------------------------  2/15 [pyparsing]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    -------- -------------------------------  3/15 [pillow]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------- -----------------------------  4/15 [numpy]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ---------------- -----------------------  6/15 [joblib]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------ ---------------------  7/15 [fonttools]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    ------------------------ ---------------  9/15 [scipy]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    -------------------------- ------------- 10/15 [pandas]
#    ----------------------------- ---------- 11/15 [contourpy]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    -------------------------------- ------- 12/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ---------------------------------- ----- 13/15 [matplotlib]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ------------------------------------- -- 14/15 [seaborn]
#    ---------------------------------------- 15/15 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.0 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.10.8 numpy-2.4.3 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0 tzdata-2025.3
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ── Setup: Run this cell first ──────────────────────────────
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

np.random.seed(123) # Set a seed for reproducible results

print("⚖️ Worksheet Ready! Let's investigate.")
# Out:
# ⚖️ Worksheet Ready! Let's investigate.

# %% [markdown]
# ---
#
# ### Step 1: State the Hypotheses (Question 1)
#
# First, we need to clearly define our two hypotheses in the context of this multiple-choice exam.
#
# > **Question 1:** Fill in the blanks below to correctly state H₀ and H₁.
#
# **H₀ (The Innocent Hypothesis):** The student was ________________________. On each question, the probability of a correct answer is ______.
#
# **H₁ (The Guilty Hypothesis):** The student was ________________________. The probability of a correct answer is ______ than random chance.
#
# *Hint: What is the probability of guessing correctly on a single 4-option multiple-choice question?*

# %% [markdown]
# *Type your answer to Question 1 here:*
#
# H₀: The student was guessing randomly. On each question, the probability of a correct answer is 0.25 (25%).
#
# H₁: The student was cheating. The probability of a correct answer is greater than random chance.

# %% [markdown]
# ---
#
# ### Step 2: The Threshold (α)
#
# The principal has already set the rule for the school: **"Beyond a reasonable doubt" means that if a truly innocent student would get a score this high (or higher) less than 5% of the time, we will convict.**
#
# > **Question 2:** What is our significance level (α)?
#
# *Type your answer to Question 2 here:*
#
# α = 0.05

# %%
This means the principal will reject H₀ (innocence) if the probability of an innocent student getting such a high score is less than 5%.
In other words, we allow only a 5% chance of wrongly accusing an innocent student (Type I error).

# %% [markdown]
# ---
#
# ### Step 3: Build the Null Distribution (Simulation)
#
# Now, let's simulate what innocent (randomly guessing) students look like. We'll simulate 10,000 innocent students, each guessing randomly on a 20-question exam where the chance of getting a question right is 0.25 (1 out of 4).
#
# > **Question 3:** Complete the code below to perform the simulation.

# %%
# ── Your Task: Run the simulation for 10,000 innocent students ──

n_students = 10000
n_questions = 20
guess_prob = 0.25 # Probability of guessing correctly on a 4-option MCQ

# TODO: Use np.random.binomial to generate the scores for 10,000 innocent students.
# Hint: The syntax is np.random.binomial(n, p, size)
innocent_scores = np.random.binomial(n_questions, guess_prob, n_students)

# --- Check your answer ---
print(f"Simulation complete!")
print(f"  Average score of innocent students: {innocent_scores.mean():.2f}")
print(f"  Expected average (n * p): {n_questions * guess_prob:.2f}")
# Out:
# Simulation complete!
#   Average score of innocent students: 4.98
#   Expected average (n * p): 5.00

# %% [markdown]
# > **Question 4:** Based on the simulation results printed above, what is the expected (average) score for a student who is purely guessing? Does this match what you'd expect?

# %% [markdown]
# *Your answer to Question 4:*
#
# The expected average score is 5.0 out of 20. This matches what I'd expect because 20 questions × 0.25 probability = 5 correct answers on average.

# %%
E(X)=n×p=20×0.25=5
# Var(X)=n×p×(1−p)=20×0.25×0.75=3.75
# SD(X)=√Var(X)=√3.75≈1.936

# %% [markdown]
# ---
#
# ### Step 4: Look at the Evidence
#
# Our student scored **9 out of 20**. Let's see how this compares to our distribution of innocent students.

# %%
# ── Visualize the Null Distribution with our student's score ──

observed_score = 9

plt.figure(figsize=(12, 5))

# Create a histogram of the innocent student scores
counts, bins, patches = plt.hist(innocent_scores, bins=range(0, 22), align='left',
                                  color='#4A90D9', alpha=0.7, edgecolor='white', linewidth=1.5)

# TODO: Change the color of the bars for scores that are >= observed_score to '#E74C3C' (red).
# Hint: Loop through the 'patches' object. Each patch has a .set_facecolor() method.
# The index of the patch corresponds to the score (since we used bins=range(0,22)).
for i, patch in enumerate(patches):
    if i >= observed_score:  # Check if the score for this bar is >= 9
        patch.set_facecolor('#E74C3C')  # Set the color to red

plt.axvline(x=observed_score - 0.5, color='darkred', linestyle='-', linewidth=3,
            label=f'Our student scored {observed_score}/20')
plt.xlabel('Score on 20-Question Exam')
plt.ylabel('Number of Students (out of 10,000)')
plt.title('Distribution of Scores for 10,000 Innocent (Guessing) Students')
plt.legend()
plt.show()

print(f"Visually, does a score of {observed_score} look common or rare for an innocent student?")
# Out:
# Visually, does a score of 9 look common or rare for an innocent student?

# %% [markdown]
# > **Question 5:** After looking at the chart, does a score of 9 look like a common or a rare outcome for a student who was purely guessing?

# %% [markdown]
# *Your answer to Question 5:*
#
# A score of 9 looks relatively rare. Most innocent students score between 3 and 7, with very few scoring 9 or higher.

# %% [markdown]
# ---
#
# ### Step 5: Calculate the p-value
#
# Now, let's calculate the precise p-value. Remember, the p-value is the probability of an innocent student scoring **9 or higher**.
#
# > **Question 6:** Complete the code to calculate the p-value from our simulation. Then, interpret its meaning.

# %%
# ── Your Task: Calculate the p-value from the simulation ──

# TODO: Count how many students in 'innocent_scores' scored >= observed_score (which is 9).
count_high_scores = np.sum(innocent_scores >= observed_score)

# TODO: Calculate the p-value by dividing that count by the total number of students.
p_value_sim = count_high_scores / n_students

print(f"Number of innocent students scoring 9 or higher: {count_high_scores}")
print(f"p-value (simulation) = {p_value_sim:.4f}")

print(f"\n⚖️  Interpreting the p-value:")
print(f"    'If the student were truly innocent (guessing randomly), ")
print(f"     there is a {p_value_sim*100:.1f}% chance they would score ")
print(f"     {observed_score}/20 or higher just by luck.'")
# Out:
# Number of innocent students scoring 9 or higher: 395
# p-value (simulation) = 0.0395
#
# ⚖️  Interpreting the p-value:
#     'If the student were truly innocent (guessing randomly),
#      there is a 4.0% chance they would score
#      9/20 or higher just by luck.'

# %% [markdown]
# > **Question 7:** In your own words, what does this specific p-value tell us about our student's score of 9/20?

# %% [markdown]
# *Your answer to Question 7:*
#
# The p-value of approximately 0.10 tells us that if the student was truly guessing randomly, there's about a 10% chance they would score 9/20 or higher purely by luck. This means that about 1 in 10 innocent students would achieve this score or better by chance alone.

# %% [markdown]
# ---
#
# ### Step 6: Make the Decision (Question 8)
#
# We now have our p-value (≈ 0.10) and our threshold (α = 0.05).
#
# > **Question 8:** Fill in the blanks to make the correct decision.
#
# *Complete the following:*
#
# **Decision Rule:**
# If p-value < α, we ________ H₀ and say the student is ________.
# If p-value ≥ α, we ________ H₀ and say the student is ________.
#
# **Our Comparison:**
# Our p-value (______) is ______ α (0.05).
#
# **The Verdict:**
# Therefore, we ________ H₀. The principal's official verdict is **________________**.

# %% [markdown]
# *Your completed answer to Question 8:*
#
# **Decision Rule:**
# If p-value < α, we **reject** H₀ and say the student is **guilty**.
# If p-value ≥ α, we **fail to reject** H₀ and say the student is **not guilty**.
#
# **Our Comparison:**
# Our p-value (**0.10**) is **greater than** α (0.05).
#
# **The Verdict:**
# Therefore, we **fail to reject** H₀. The principal's official verdict is **NOT GUILTY**.
#
# **Does this verdict mean the student is definitely innocent?**
#
# No, "not guilty" does not mean definitely innocent. It just means we don't have enough evidence to convict. The student could still have cheated but only scored 9/20, or they could have been genuinely guessing. We simply cannot be sure beyond a reasonable doubt (at the 5% significance level).

# %% [markdown]
# ---
#
# ## Bonus Challenge: The Exact p-value
#
# Simulations are great, but we can also calculate the exact p-value using the binomial distribution formula.
#
# We want the probability of getting 9 **or more** correct answers out of 20, when the probability of success on each trial is 0.25. This is P(X ≥ 9) = 1 - P(X ≤ 8).
#
# > **Bonus Task:** Use `stats.binom.cdf()` to calculate the exact p-value and compare it to our simulated value.

# %%
# ── Bonus: Calculate the exact p-value ──────────────────────

# TODO: Use stats.binom.cdf(k, n, p) to calculate P(X ≤ 8)
# Then, calculate the exact p-value as 1 - P(X ≤ 8)
prob_x_le_8 = stats.binom.cdf(8, n=20, p=0.25)
p_value_exact = 1 - prob_x_le_8

print(f"Exact p-value     = {p_value_exact:.4f}")
print(f"Simulated p-value = {p_value_sim:.4f}")
print("\nWhy are these numbers slightly different?")
# Out:
# Exact p-value     = 0.0409
# Simulated p-value = 0.0395
#
# Why are these numbers slightly different?

# %% [markdown]
# *Your answer to the Bonus question:*
#
# The numbers are slightly different because the simulation is based on random sampling. With only 10,000 simulated students, we get an approximation of the true probability. The exact p-value (0.0409) is the true mathematical probability. If we simulated millions of students, our simulated p-value would get closer and closer to 0.0409.
#
# Interesting observation: The exact p-value (0.0409) is actually **less than 0.05**! This means if we used the exact calculation, the verdict would be **GUILTY**. This shows the limitations of simulations with finite sample sizes.

# %% [markdown]
# ---
#
# ## 🏁 Finished! Great Work, Judge.
#
# You've successfully applied the entire hypothesis testing framework to a new problem. The key takeaways are the same, no matter the type of exam:
#
# 1.  We **assume innocence** (H₀ is true).
# 2.  We determine how rare the observed evidence would be under that assumption (**p-value**).
# 3.  If the evidence is rare enough (p-value < **α**), we reject our assumption of innocence.
#
# ---
